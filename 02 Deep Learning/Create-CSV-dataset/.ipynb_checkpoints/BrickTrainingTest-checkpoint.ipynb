# %%
# %matplotlib inline

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from numpy import genfromtxt

# %%
#define parameters
steps = 20
epochs = 25
batch_size = 8

# %%
! python ../keras-retinanet/keras_retinanet/bin/train.py
# Out:
# Using TensorFlow backend.
# 2020-03-02 19:52:44.997067: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer.so.6'; dlerror: libnvinfer.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: ${LD_LIBRARY_PATH}:/usr/lib/x86_64-linux-gnu/gazebo-9/plugins
# 2020-03-02 19:52:44.997171: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer_plugin.so.6'; dlerror: libnvinfer_plugin.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: ${LD_LIBRARY_PATH}:/usr/lib/x86_64-linux-gnu/gazebo-9/plugins
# 2020-03-02 19:52:44.997184: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:30] Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# usage: train.py [-h]
# ...

# %%
# !python ../keras-retinanet/keras_retinanet/bin/train.py --steps 20 --epochs 25 --snapshot-path ../keras-retinanet/snapshots \
--weights ../keras-retinanet/snapshots/resnet50_coco_best_v2.1.0.h5 \
--no-resize --batch-size 8 \
--compute-val-loss\
csv train_set.csv classes.csv \
--val-annotations val_set.csv
# Out:
# Using TensorFlow backend.
# 2020-03-02 19:55:12.579601: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer.so.6'; dlerror: libnvinfer.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: ${LD_LIBRARY_PATH}:/usr/lib/x86_64-linux-gnu/gazebo-9/plugins
# 2020-03-02 19:55:12.579709: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer_plugin.so.6'; dlerror: libnvinfer_plugin.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: ${LD_LIBRARY_PATH}:/usr/lib/x86_64-linux-gnu/gazebo-9/plugins
# 2020-03-02 19:55:12.579725: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:30] Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Creating model, this may take a second...
# ...

# %%
loss_data = genfromtxt('losses1.csv', delimiter=',')
loss_data = loss_data.T
print(loss_data)
# Out:
# [[2.31069171 1.84712988 1.67368496 1.41880066 1.18204536 1.09761565
#   0.94861989 0.81870823 0.74875091 0.67384853 0.63082648 0.57140481
#   0.57459167 0.53616043 0.51653962 0.48259635 0.49315384 0.44679572
#   0.45922073 0.44657043 0.44228438 0.43256684 0.41563227 0.42136744
#   0.39228719]
#  [2.14622736 1.86233163 1.65816164 1.46856081 1.32490516 1.1759702
#   1.05211353 0.93584257 0.83818686 0.77066326 0.72598195 0.69632685
#   0.66584969 0.64890176 0.62747538 0.61615086 0.60839117 0.60413986
#   0.58438158 0.5793823  0.56708133 0.56256646 0.55262673 0.54827887
#   0.54267544]]

# %%
plt.figure(figsize=(4, 3), dpi=200)
plt.plot(range(1, 1 + len(loss_data[0])), loss_data[0])
plt.plot(range(1, 1 + len(loss_data[1])), loss_data[1])
plt.legend(['Train Loss','Validation Loss'])
plt.title('Steps: 20, BS: 8, BB: renet50-coco')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.savefig('./train-val-loss.png',bbox_inches='tight')
