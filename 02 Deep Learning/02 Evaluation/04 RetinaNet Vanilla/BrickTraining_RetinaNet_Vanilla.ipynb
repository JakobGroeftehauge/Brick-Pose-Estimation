# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from numpy import genfromtxt

# %%
#define parameters
steps = 20
epochs = 25
batch_size = 8

# %% [markdown]
# ## Train on On Pallet

# %%
# !python "../../keras-retinanet-vanilla/keras_retinanet/bin/train.py" --steps 396 --epochs 25 \
--weights "../../RetinaNet with Angle/keras_retinanet/resnet50_coco_best_v2.1.0.h5" \
--snapshot-path "./02 On Pallet Dataset/01 Snapshots" \
--batch-size 1 \
--compute-val-loss\
--name "Vanilla_OP_train_set_14-04_05" \
csv "../OP_vanilla_train_set_14-04.csv" "../classes.csv" \
--val-annotations "../OP_vanilla_val_set_14-04.csv"
# Out:
# Using TensorFlow backend.
# 2020-05-07 13:10:34.619871: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer.so.6
# 2020-05-07 13:10:34.621348: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer_plugin.so.6
# Creating model, this may take a second...
# 2020-05-07 13:10:35.500002: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-07 13:10:35.527200: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-07 13:10:35.528212: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:00:05.0 name: Quadro P5000 computeCapability: 6.1
# ...

# %% [markdown]
# ## Continue Training from Snapshot

# %%
# !python "../../RetinaNet_Rotated_Comb/keras_retinanet/bin/train.py" --steps 99 --epochs 50 \
--snapshot "./02 On Pallet Dataset/01 Snapshots/resnet50_csv_25.h5" \
--initial-epoch 25 \
--snapshot-path "./02 On Pallet Dataset/01 Snapshots" \
--batch-size 4 \
--compute-val-loss\
--random-transform\
--name "Rotated_Comb_OP_train_set_14-04_rndTrans_BS4_25-50" \
csv "../OP_train_set_14-04.csv" "../classes.csv" \
--val-annotations "../OP_val_set_14-04.csv"

# %% [markdown]
# ## Train on Simple Dataset

# %%
# !python "../../keras-retinanet-vanilla/keras_retinanet/bin/train.py" --steps 162 --epochs 25 \
--weights "../../RetinaNet with Angle/keras_retinanet/resnet50_coco_best_v2.1.0.h5" \
--snapshot-path "./01 Simple Dataset/01 Snapshots" \
--batch-size 1 \
--compute-val-loss\
--name "Vanilla_train_set_18-03_05" \
csv "../vanilla_train_set_18-03.csv" "../classes.csv" \
--val-annotations "../vanilla_val_set_18-03.csv"
# Out:
# Using TensorFlow backend.
# 2020-05-08 04:35:47.255031: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer.so.6
# 2020-05-08 04:35:47.256657: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer_plugin.so.6
# Creating model, this may take a second...
# 2020-05-08 04:35:48.106209: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-08 04:35:48.134565: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-08 04:35:48.135637: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:00:05.0 name: Quadro P5000 computeCapability: 6.1
# ...
