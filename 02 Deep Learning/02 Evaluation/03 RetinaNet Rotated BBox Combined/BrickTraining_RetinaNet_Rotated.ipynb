# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from numpy import genfromtxt

# %%
#define parameters
steps = 20
epochs = 25
batch_size = 8

# %% [markdown]
# ## Train on On Pallet

# %%
# !python "../../RetinaNet_Rotated_Comb/keras_retinanet/bin/train.py" --steps 396 --epochs 25 \
--weights "../../RetinaNet_with_Angle/keras_retinanet/resnet50_coco_best_v2.1.0.h5" \
--snapshot-path "./02 On Pallet Dataset/01 Snapshots" \
--batch-size 1 \
--compute-val-loss\
--name "Rotated_Comb_OP_rectified_04" \
csv "../OP_rectified_train_set_04.csv" "../classes.csv" \
--val-annotations "../OP_rectified_val_set_04.csv"
# Out:
# Using TensorFlow backend.
# 2020-05-19 09:23:14.054539: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer.so.6
# 2020-05-19 09:23:14.056386: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer_plugin.so.6
# Creating model, this may take a second...
# 2020-05-19 09:23:15.383291: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-19 09:23:15.417577: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-19 09:23:15.418801: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:00:05.0 name: Quadro P5000 computeCapability: 6.1
# ...

# %% [markdown]
# ## Continue Training from Snapshot

# %%
# !python "../../RetinaNet_Rotated_Comb/keras_retinanet/bin/train.py" --steps 99 --epochs 50 \
--snapshot "./02 On Pallet Dataset/01 Snapshots/resnet50_csv_25.h5" \
--initial-epoch 25 \
--snapshot-path "./02 On Pallet Dataset/01 Snapshots" \
--batch-size 4 \
--compute-val-loss\
--random-transform\
--name "Rotated_Comb_OP_train_set_14-04_rndTrans_BS4_25-50" \
csv "../OP_train_set_14-04.csv" "../classes.csv" \
--val-annotations "../OP_val_set_14-04.csv"

# %% [markdown]
# ## Train on Simple Dataset

# %%
# !python "../../RetinaNet_Rotated_Comb/keras_retinanet/bin/train.py" --steps 162 --epochs 25 \
--weights "../../RetinaNet with Angle/keras_retinanet/resnet50_coco_best_v2.1.0.h5" \
--snapshot-path "./01 Simple Dataset/01 Snapshots" \
--batch-size 1 \
--compute-val-loss\
--name "Rotated_Comb_train_set_18-03_05" \
csv "../train_set_18-03.csv" "../classes.csv" \
--val-annotations "../val_set_18-03.csv"
# Out:
# Using TensorFlow backend.
# 2020-05-05 01:35:29.749810: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer.so.6
# 2020-05-05 01:35:29.806443: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer_plugin.so.6
# Creating model, this may take a second...
# 2020-05-05 01:35:32.405989: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-05 01:35:32.481301: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-05 01:35:32.482430: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:00:05.0 name: Quadro P5000 computeCapability: 6.1
# ...

# %% [markdown]
# ## DOTA

# %%
# !python "../../RetinaNet_Rotated_Comb/keras_retinanet/bin/train.py" --steps 104 --epochs 25 \
--weights "../../RetinaNet_with_Angle/keras_retinanet/resnet50_coco_best_v2.1.0.h5" \
--snapshot-path "./03 DOTA/01 Snapshots" \
--batch-size 2 \
--random-transform \
--freeze-backbone \
--compute-val-loss\
--name "Rotated_Comb_DOTA_transform" \
csv "../train_DOTA16-06.csv" "../classes_DOTA.csv" \
--val-annotations "../val_DOTA16-06.csv"
# Out:
# Using TensorFlow backend.
# 2020-06-16 09:08:56.077116: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer.so.6
# 2020-06-16 09:08:56.134845: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer_plugin.so.6
# Creating model, this may take a second...
# 2020-06-16 09:08:58.560119: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-06-16 09:08:58.633545: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-16 09:08:58.634736: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:00:05.0 name: Quadro P5000 computeCapability: 6.1
# ...

# %%
# !python "../../RetinaNet_Rotated_Comb/keras_retinanet/bin/debug.py" \
--annotations \
--no-gui --output-dir "./03 DOTA/02 Anchor Test/" \
csv "../train_DOTA16-06.csv" "../classes_DOTA.csv"
# Out:
# Using TensorFlow backend.
# 2020-06-16 07:07:02.241651: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer.so.6
# 2020-06-16 07:07:02.243164: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer_plugin.so.6
