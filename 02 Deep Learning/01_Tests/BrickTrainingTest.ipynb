# %%
#%matplotlib inline

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from numpy import genfromtxt

# %%
#define parameters
steps = 20
epochs = 25
batch_size = 8

# %%
# !python "../RetinaNet with Angle/keras_retinanet/bin/train.py" --steps 162 --epochs 25 \
--weights "../RetinaNet with Angle/keras_retinanet/resnet50_coco_best_v2.1.0.h5" \
--freeze-backbone \
--batch-size 1 \
--compute-val-loss\
csv train_set_18-03.csv classes.csv \
--val-annotations val_set_18-03.csv
# Out:
# Using TensorFlow backend.
# 2020-03-31 06:10:12.422248: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer.so.6
# 2020-03-31 06:10:12.424238: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer_plugin.so.6
# Creating model, this may take a second...
# 2020-03-31 06:10:13.463241: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-03-31 06:10:13.486762: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-31 06:10:13.487937: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:00:05.0 name: Quadro P5000 computeCapability: 6.1
# ...

# %% [markdown]
# ## Retraining of Test networks

# %%
# !python "../RetinaNet with Angle/keras_retinanet/bin/train.py" --steps 162 --epochs 40 \
--snapshot snapshots/resnet50_csv_25.h5 \
--initial-epoch 25 \
--compute-val-loss\
csv train_set_18-03.csv classes.csv \
--val-annotations val_set_18-03.csv
# Out:
# Using TensorFlow backend.
# 2020-03-31 06:31:26.981312: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer.so.6
# 2020-03-31 06:31:26.983063: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer_plugin.so.6
# Loading model, this may take a second...
# 2020-03-31 06:31:28.091411: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-03-31 06:31:28.119932: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-31 06:31:28.121054: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:00:05.0 name: Quadro P5000 computeCapability: 6.1
# ...

# %%
# !python ../keras-retinanet/keras_retinanet/bin/train.py --steps 162 --epochs 35 --snapshot-path ../keras-retinanet/snapshots \
--weights ../keras-retinanet/snapshots/resnet50_coco_best_v2.1.0.h5 \
--batch-size 1 \
--compute-val-loss\
csv train_set_03-03.csv classes.csv \
--val-annotations val_set_03-03.csv

# %%
# !python ../keras-retinanet/keras_retinanet/bin/train.py --steps 162 --epochs 50 --snapshot-path ../keras-retinanet/snapshots \
--snapshot ../keras-retinanet/snapshots/resnet50_csv_25.h5 \
--initial-epoch 25 \
--no-resize --batch-size 1 \
--compute-val-loss\
csv train_set_03-03.csv classes.csv \
--val-annotations val_set_03-03.csv

# %%
loss_data = genfromtxt('val_train_set_03-03_losses.csv', delimiter=',')
loss_data = loss_data.T
print(loss_data)

# %%
plt.figure(figsize=(4, 3), dpi=200)
plt.plot(range(1, 1 + len(loss_data[0])), loss_data[0])
plt.plot(range(1, 1 + len(loss_data[1])), loss_data[1])
plt.legend(['Train Loss','Validation Loss'])
plt.title('Steps: 162, BS: 1, BB: renet50-coco, resized')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.savefig('./val_train_set_03-03_losses_resize.png',bbox_inches='tight')
